# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/Users/salmanosman/Downloads/titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # Cleaning the Data

# %%
df = df.dropna(subset = ['deck','embark_town'])

# %%
df.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        0
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     0
# alive           0
# alone           0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   201.000000  201.000000   201  182.000000  201.000000  201.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   106         NaN         NaN         NaN
# mean      0.666667    1.199005   NaN   35.623187    0.447761    0.442786
# std       0.472582    0.529338   NaN   15.671615    0.631274    0.733458
# min       0.000000    1.000000   NaN    0.920000    0.000000    0.000000
# 25%       0.000000    1.000000   NaN   24.000000    0.000000    0.000000
# 50%       1.000000    1.000000   NaN   36.000000    0.000000    0.000000
# 75%       1.000000    1.000000   NaN   47.750000    1.000000    1.000000
# max       1.000000    3.000000   NaN   80.000000    3.000000    4.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   201.000000      201    201  201        201  201          201   201
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  First  man      False    C  Southampton   yes
# freq           NaN      128    173   99        102   59          128   134
# mean     76.305307      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      74.891320      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%      28.712500      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      55.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      90.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#         alone
# count     201
# unique      2
# top     False
# freq      110
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
df['age'] = df['age'].fillna(df['age'].mean())
# Out:
# /Users/salmanosman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df['age'] = df['age'].astype(int)
# Out:
# /Users/salmanosman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['age']
# Out:
# 1      38
# 3      35
# 6      54
# 10      4
# 11     58
#        ..
# 871    47
# 872    33
# 879    56
# 887    19
# 889    26
# Name: age, Length: 201, dtype: int64

# %%
df = df.drop(columns = ['alive','class'])

# %% [markdown]
# The 'alive' columns is the same as 'survived'. If someone is not alive, he has not survived and vice-versa. Likewise, 'class' is a categorical representation of 'pclass', so it is not needed.

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked    who  \
# 1           1       1  female   38      1      0  71.2833        C  woman
# 3           1       1  female   35      1      0  53.1000        S  woman
# 6           0       1    male   54      0      0  51.8625        S    man
# 10          1       3  female    4      1      1  16.7000        S  child
# 11          1       1  female   58      0      0  26.5500        S  woman
# ..        ...     ...     ...  ...    ...    ...      ...      ...    ...
# 871         1       1  female   47      1      1  52.5542        S  woman
# 872         0       1    male   33      0      0   5.0000        S    man
# 879         1       1  female   56      0      1  83.1583        C  woman
# 887         1       1  female   19      0      0  30.0000        S  woman
# 889         1       1    male   26      0      0  30.0000        C    man
#
#      adult_male deck  embark_town  alone
# 1         False    C    Cherbourg  False
# 3         False    C  Southampton  False
# 6          True    E  Southampton   True
# 10        False    G  Southampton  False
# 11        False    C  Southampton   True
# ..          ...  ...          ...    ...
# 871       False    D  Southampton  False
# 872        True    B  Southampton   True
# 879       False    C    Cherbourg  False
# 887       False    B  Southampton   True
# 889        True    C    Cherbourg   True
#
# [201 rows x 13 columns]

# %%
df = df.drop(columns = ['adult_male','embarked'])

# %% [markdown]
# 'Adult_male' incorportated into 'who', so I have removed it as a column. 'Embarked' is a duplicate of 'embark_town', so it is also not needed.

# %%
# Visually Examining data to see outliers

# %%
sns.boxplot(x = df['pclass'], y = df['fare'])

# %%
sns.boxplot(df['fare'])

# %%
#Removing outliers in fare

# %%
from scipy import stats
import numpy as np

# %%
z_score = stats.zscore(df['fare'])
abs_z_score = np.abs(z_score)
filtered_fare = (abs_z_score < 3)

# %%
df_1 = df[filtered_fare]

# %%
df_1.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   199.000000  199.000000   199  199.000000  199.000000  199.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   104         NaN         NaN         NaN
# mean      0.663317    1.201005   NaN   35.552764    0.452261    0.442211
# std       0.473767    0.531625   NaN   14.994476    0.632841    0.735415
# min       0.000000    1.000000   NaN    0.000000    0.000000    0.000000
# 25%       0.000000    1.000000   NaN   25.000000    0.000000    0.000000
# 50%       1.000000    1.000000   NaN   35.000000    0.000000    0.000000
# 75%       1.000000    1.000000   NaN   47.000000    1.000000    1.000000
# max       1.000000    3.000000   NaN   80.000000    3.000000    4.000000
#
#               fare  who deck  embark_town  alone
# count   199.000000  199  199          199    199
# unique         NaN    3    7            3      2
# top            NaN  man    C  Southampton  False
# freq           NaN   97   59          128    109
# mean     71.923158  NaN  NaN          NaN    NaN
# std      61.038440  NaN  NaN          NaN    NaN
# min       0.000000  NaN  NaN          NaN    NaN
# 25%      28.606250  NaN  NaN          NaN    NaN
# 50%      55.000000  NaN  NaN          NaN    NaN
# 75%      89.104200  NaN  NaN          NaN    NaN
# max     263.000000  NaN  NaN          NaN    NaN

# %%
sns.boxplot(df_1['fare'])

# %%
#Outliers successfully removed from fares

# %%
#Further visualisations

# %%
sns.scatterplot(x=df_1['fare'], y=df_1['survived']);

# %%
sns.scatterplot(x=df_1['age'], y=df_1['fare'], hue = df_1['survived'], size = df_1['pclass']);

# %% [markdown]
# The scatter plot above shows that most of those that survived were adults in first class.

# %%
sns.scatterplot(x=df_1['age'], y=df_1['fare'], hue = df_1['pclass'], size = df_1['survived']);

# %%
sns.violinplot(x=df_1['survived'],y=df_1['age'])

# %% [markdown]
# This violin plot shows that very few people survived who were over 60, and bulk of those that survived were adults between 30 and 40 years of age.

# %%
sns.regplot(x=df_1['age'],y=df_1['fare']);

# %%
df_2 = df_1.groupby(['sex'], as_index = False)['survived'].sum()
df_2
# Out:
#       sex  survived
# 0  female        89
# 1    male        43

# %%
df_3 = df_1.groupby(['who'], as_index = False)['survived'].sum()
df_3
# Out:
#      who  survived
# 0  child        11
# 1    man        36
# 2  woman        85

# %%
df_4 = df_1.groupby(['pclass'], as_index = False)['survived'].sum()
df_4
# Out:
#    pclass  survived
# 0     1.0     113.0
# 1     2.0      13.0
# 2     3.0       6.0

# %%
#Correlations

# %%
df_1.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare     alone
# survived  1.000000 -0.030733 -0.236721  0.139840  0.038097  0.103458 -0.164475
# pclass   -0.030733  1.000000 -0.284545 -0.091429  0.055697 -0.359088  0.055396
# age      -0.236721 -0.284545  1.000000 -0.148894 -0.264106 -0.106678  0.191880
# sibsp     0.139840 -0.091429 -0.148894  1.000000  0.262628  0.410625 -0.651024
# parch     0.038097  0.055697 -0.264106  0.262628  1.000000  0.468931 -0.547771
# fare      0.103458 -0.359088 -0.106678  0.410625  0.468931  1.000000 -0.384968
# alone    -0.164475  0.055396  0.191880 -0.651024 -0.547771 -0.384968  1.000000

# %%
#No apparent relationship between survival and any of numeric independent variables

# %% [markdown]
# #Determining p-values

# %%
# Survived vs age

# %%
pearson_coef, p_value = stats.pearsonr(df_1['age'], df_1['survived'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.23672091217397523  with a P-value of P = 0.0007618468612381202

# %%
# Weak relationship between age and survival, however p-value suggests that it is significant.

# %%
# Survived vs sibsp

# %%
pearson_coef, p_value = stats.pearsonr(df_1['sibsp'], df_1['survived'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.1398402451351529  with a P-value of P = 0.048843811313064124

# %%
# Weak relationship between sibsp and survived and moderate evidence that the correlation is significant

# %%
# Survived vs parch

# %%
pearson_coef, p_value = stats.pearsonr(df_1['parch'], df_1['survived'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.038096545529770626  with a P-value of P = 0.5931849301181782

# %%
# Weak relationship between parch and survived. Correlation is insignificant as p-value is > 0.1

# %%
# Survived vs alone

# %%
pearson_coef, p_value = stats.pearsonr(df_1['alone'], df_1['survived'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.16447499984247232  with a P-value of P = 0.020264127650185874

# %%
# Weak relationship between alone and survived, moderate evidence that the correlation is significant.

# %% [markdown]
# #Of numerical variables, include pclass, fare, Age, Sibsp and alone in model. Discard others.

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp     fare    who  alone  sex_female  \
# 1         1.0     1.0  female  38.0    1.0  71.2833  woman  False           1
# 3         1.0     1.0  female  35.0    1.0  53.1000  woman  False           1
# 6         0.0     1.0    male  54.0    0.0  51.8625    man   True           0
# 10        1.0     3.0  female   4.0    1.0  16.7000  child  False           1
# 11        1.0     1.0  female  58.0    0.0  26.5500  woman   True           1
# ..        ...     ...     ...   ...    ...      ...    ...    ...         ...
# 871       1.0     1.0  female  47.0    1.0  52.5542  woman  False           1
# 872       0.0     1.0    male  33.0    0.0   5.0000    man   True           0
# 879       1.0     1.0  female  56.0    0.0  83.1583  woman  False           1
# 887       1.0     1.0  female  19.0    0.0  30.0000  woman   True           1
# 889       1.0     1.0    male  26.0    0.0  30.0000    man   True           0
#
#      sex_male  who_child  who_man  who_woman  alone_False  alone_True
# 1           0          0        0          1            1           0
# 3           0          0        0          1            1           0
# 6           1          0        1          0            0           1
# 10          0          1        0          0            1           0
# 11          0          0        0          1            0           1
# ..        ...        ...      ...        ...          ...         ...
# 871         0          0        0          1            1           0
# 872         1          0        1          0            0           1
# 879         0          0        0          1            1           0
# 887         0          0        0          1            0           1
# 889         1          0        1          0            0           1
#
# [199 rows x 15 columns]

# %%
df_1 = df_1.drop(columns = ['embark_town'])

# %%
df_1
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare    who deck  alone
# 1           1       1  female   38      1      0  71.2833  woman    C  False
# 3           1       1  female   35      1      0  53.1000  woman    C  False
# 6           0       1    male   54      0      0  51.8625    man    E   True
# 10          1       3  female    4      1      1  16.7000  child    G  False
# 11          1       1  female   58      0      0  26.5500  woman    C   True
# ..        ...     ...     ...  ...    ...    ...      ...    ...  ...    ...
# 871         1       1  female   47      1      1  52.5542  woman    D  False
# 872         0       1    male   33      0      0   5.0000    man    B   True
# 879         1       1  female   56      0      1  83.1583  woman    C  False
# 887         1       1  female   19      0      0  30.0000  woman    B   True
# 889         1       1    male   26      0      0  30.0000    man    C   True
#
# [199 rows x 10 columns]

# %%
sex_dummies = pd.get_dummies(df_1['sex'], prefix = 'sex')
who_dummies = pd.get_dummies(df['who'], prefix = 'who')
deck_dummies = pd.get_dummies(df['deck'], prefix = 'deck')
alone_dummies = pd.get_dummies(df['alone'], prefix = 'alone')

# %%
df_1 = pd.concat([df_1, sex_dummies, who_dummies, deck_dummies, alone_dummies], axis =1)

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  alone  \
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833  woman  False
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000  woman  False
# 6         0.0     1.0    male  54.0    0.0    0.0  51.8625    man   True
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000  child  False
# 11        1.0     1.0  female  58.0    0.0    0.0  26.5500  woman   True
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 871       1.0     1.0  female  47.0    1.0    1.0  52.5542  woman  False
# 872       0.0     1.0    male  33.0    0.0    0.0   5.0000    man   True
# 879       1.0     1.0  female  56.0    0.0    1.0  83.1583  woman  False
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000  woman   True
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000    man   True
#
#      sex_female  ...  who_woman  deck_A  deck_B  deck_C  deck_D  deck_E  \
# 1           1.0  ...          1       0       0       1       0       0
# 3           1.0  ...          1       0       0       1       0       0
# 6           0.0  ...          0       0       0       0       0       1
# 10          1.0  ...          0       0       0       0       0       0
# 11          1.0  ...          1       0       0       1       0       0
# ..          ...  ...        ...     ...     ...     ...     ...     ...
# 871         1.0  ...          1       0       0       0       1       0
# 872         0.0  ...          0       0       1       0       0       0
# 879         1.0  ...          1       0       0       1       0       0
# 887         1.0  ...          1       0       1       0       0       0
# 889         0.0  ...          0       0       0       1       0       0
#
#      deck_F  deck_G  alone_False  alone_True
# 1         0       0            1           0
# 3         0       0            1           0
# 6         0       0            0           1
# 10        0       1            1           0
# 11        0       0            0           1
# ..      ...     ...          ...         ...
# 871       0       0            1           0
# 872       0       0            0           1
# 879       0       0            1           0
# 887       0       0            0           1
# 889       0       0            0           1
#
# [201 rows x 23 columns]

# %%
df_1 = df_1.drop(columns = ['deck'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-a95f6929db48> in <module>
# ----> 1 df_1 = df_1.drop(columns = ['deck'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['deck'] not found in axis"

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  alone  \
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833  woman  False
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000  woman  False
# 6         0.0     1.0    male  54.0    0.0    0.0  51.8625    man   True
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000  child  False
# 11        1.0     1.0  female  58.0    0.0    0.0  26.5500  woman   True
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 871       1.0     1.0  female  47.0    1.0    1.0  52.5542  woman  False
# 872       0.0     1.0    male  33.0    0.0    0.0   5.0000    man   True
# 879       1.0     1.0  female  56.0    0.0    1.0  83.1583  woman  False
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000  woman   True
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000    man   True
#
#      sex_female  ...  who_woman  deck_A  deck_B  deck_C  deck_D  deck_E  \
# 1           1.0  ...          1       0       0       1       0       0
# 3           1.0  ...          1       0       0       1       0       0
# 6           0.0  ...          0       0       0       0       0       1
# 10          1.0  ...          0       0       0       0       0       0
# 11          1.0  ...          1       0       0       1       0       0
# ..          ...  ...        ...     ...     ...     ...     ...     ...
# 871         1.0  ...          1       0       0       0       1       0
# 872         0.0  ...          0       0       1       0       0       0
# 879         1.0  ...          1       0       0       1       0       0
# 887         1.0  ...          1       0       1       0       0       0
# 889         0.0  ...          0       0       0       1       0       0
#
#      deck_F  deck_G  alone_False  alone_True
# 1         0       0            1           0
# 3         0       0            1           0
# 6         0       0            0           1
# 10        0       1            1           0
# 11        0       0            0           1
# ..      ...     ...          ...         ...
# 871       0       0            1           0
# 872       0       0            0           1
# 879       0       0            1           0
# 887       0       0            0           1
# 889       0       0            0           1
#
# [201 rows x 23 columns]

# %%
df_1 = df_1.dropna()

# %%
df_1['sex_female'] = df_1['sex_female'].astype(int)
# Out:
# /Users/salmanosman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1['sex_male'] = df_1['sex_male'].astype(int)
# Out:
# /Users/salmanosman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  alone  \
# 1         1.0     1.0  female  38.0    1.0    0.0  71.2833  woman  False
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000  woman  False
# 6         0.0     1.0    male  54.0    0.0    0.0  51.8625    man   True
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000  child  False
# 11        1.0     1.0  female  58.0    0.0    0.0  26.5500  woman   True
# ..        ...     ...     ...   ...    ...    ...      ...    ...    ...
# 871       1.0     1.0  female  47.0    1.0    1.0  52.5542  woman  False
# 872       0.0     1.0    male  33.0    0.0    0.0   5.0000    man   True
# 879       1.0     1.0  female  56.0    0.0    1.0  83.1583  woman  False
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000  woman   True
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000    man   True
#
#      sex_female  ...  who_woman  deck_A  deck_B  deck_C  deck_D  deck_E  \
# 1             1  ...          1       0       0       1       0       0
# 3             1  ...          1       0       0       1       0       0
# 6             0  ...          0       0       0       0       0       1
# 10            1  ...          0       0       0       0       0       0
# 11            1  ...          1       0       0       1       0       0
# ..          ...  ...        ...     ...     ...     ...     ...     ...
# 871           1  ...          1       0       0       0       1       0
# 872           0  ...          0       0       1       0       0       0
# 879           1  ...          1       0       0       1       0       0
# 887           1  ...          1       0       1       0       0       0
# 889           0  ...          0       0       0       1       0       0
#
#      deck_F  deck_G  alone_False  alone_True
# 1         0       0            1           0
# 3         0       0            1           0
# 6         0       0            0           1
# 10        0       1            1           0
# 11        0       0            0           1
# ..      ...     ...          ...         ...
# 871       0       0            1           0
# 872       0       0            0           1
# 879       0       0            1           0
# 887       0       0            0           1
# 889       0       0            0           1
#
# [199 rows x 23 columns]

# %%
df_1.corr()
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.030733 -0.236721  0.139840  0.038097  0.103458
# pclass      -0.030733  1.000000 -0.284545 -0.091429  0.055697 -0.359088
# age         -0.236721 -0.284545  1.000000 -0.148894 -0.264106 -0.106678
# sibsp        0.139840 -0.091429 -0.148894  1.000000  0.262628  0.410625
# parch        0.038097  0.055697 -0.264106  0.262628  1.000000  0.468931
# fare         0.103458 -0.359088 -0.106678  0.410625  0.468931  1.000000
# sex_female   0.553187  0.055104 -0.173214  0.143998  0.109579  0.236056
# sex_male    -0.553187 -0.055104  0.173214 -0.143998 -0.109579 -0.236056
# who_child    0.102284  0.283286 -0.535964  0.164965  0.339636  0.023692
# who_man     -0.602933 -0.123182  0.322224 -0.189034 -0.204127 -0.228198
# who_woman    0.555294 -0.016952 -0.057569  0.108052  0.036417  0.217632
# deck_A      -0.118812 -0.108226  0.139620 -0.144254 -0.120222 -0.151468
# deck_B       0.064007 -0.199007 -0.046342 -0.047335  0.116259  0.212051
# deck_C      -0.096291 -0.246069  0.015733  0.197254  0.028642  0.300978
# deck_D       0.088931 -0.067090  0.096440 -0.019790 -0.084595 -0.107492
# deck_E       0.080294  0.092037  0.068880 -0.096918 -0.077403 -0.186186
# deck_F      -0.026814  0.590082 -0.235476  0.036101  0.034688 -0.231117
# deck_G      -0.049496  0.485882 -0.199203  0.010831  0.157715 -0.137241
# alone_False  0.164475 -0.055396 -0.191880  0.651024  0.547771  0.384968
# alone_True  -0.164475  0.055396  0.191880 -0.651024 -0.547771 -0.384968
#
#              sex_female  sex_male  who_child   who_man  who_woman    deck_A  \
# survived       0.553187 -0.553187   0.102284 -0.602933   0.555294 -0.118812
# pclass         0.055104 -0.055104   0.283286 -0.123182  -0.016952 -0.108226
# age           -0.173214  0.173214  -0.535964  0.322224  -0.057569  0.139620
# sibsp          0.143998 -0.143998   0.164965 -0.189034   0.108052 -0.144254
# parch          0.109579 -0.109579   0.339636 -0.204127   0.036417 -0.120222
# fare           0.236056 -0.236056   0.023692 -0.228198   0.217632 -0.151468
# sex_female     1.000000 -1.000000  -0.008388 -0.932032   0.941138 -0.234778
# sex_male      -1.000000  1.000000   0.008388  0.932032  -0.941138  0.234778
# who_child     -0.008388  0.008388   1.000000 -0.257811  -0.237801  0.001548
# who_man       -0.932032  0.932032  -0.257811  1.000000  -0.877171  0.216624
# who_woman      0.941138 -0.941138  -0.237801 -0.877171   1.000000 -0.218541
# deck_A        -0.234778  0.234778   0.001548  0.216624  -0.218541  1.000000
# deck_B         0.109324 -0.109324   0.009435 -0.096726   0.092549 -0.149902
# deck_C        -0.025681  0.025681  -0.082567  0.049335  -0.008563 -0.185353
# deck_D         0.060760 -0.060760  -0.117874 -0.029340   0.088076 -0.127303
# deck_E        -0.007569  0.007569  -0.060367  0.011002   0.018941 -0.124984
# deck_F        -0.049103  0.049103   0.259305 -0.054384  -0.074197 -0.075483
# deck_G         0.149854 -0.149854   0.251942 -0.139669   0.015199 -0.040893
# alone_False    0.201423 -0.201423   0.240228 -0.265228   0.147245 -0.199484
# alone_True    -0.201423  0.201423  -0.240228  0.265228  -0.147245  0.199484
#
#                deck_B    deck_C    deck_D    deck_E    deck_F    deck_G  \
# survived     0.064007 -0.096291  0.088931  0.080294 -0.026814 -0.049496
# pclass      -0.199007 -0.246069 -0.067090  0.092037  0.590082  0.485882
# age         -0.046342  0.015733  0.096440  0.068880 -0.235476 -0.199203
# sibsp       -0.047335  0.197254 -0.019790 -0.096918  0.036101  0.010831
# parch        0.116259  0.028642 -0.084595 -0.077403  0.034688  0.157715
# fare         0.212051  0.300978 -0.107492 -0.186186 -0.231117 -0.137241
# sex_female   0.109324 -0.025681  0.060760 -0.007569 -0.049103  0.149854
# sex_male    -0.109324  0.025681 -0.060760  0.007569  0.049103 -0.149854
# who_child    0.009435 -0.082567 -0.117874 -0.060367  0.259305  0.251942
# who_man     -0.096726  0.049335 -0.029340  0.011002 -0.054384 -0.139669
# who_woman    0.092549 -0.008563  0.088076  0.018941 -0.074197  0.015199
# deck_A      -0.149902 -0.185353 -0.127303 -0.124984 -0.075483 -0.040893
# deck_B       1.000000 -0.340827 -0.234086 -0.229820 -0.138799 -0.075194
# deck_C      -0.340827  1.000000 -0.289444 -0.284170 -0.171624 -0.092977
# deck_D      -0.234086 -0.289444  1.000000 -0.195173 -0.117874 -0.063858
# deck_E      -0.229820 -0.284170 -0.195173  1.000000 -0.115726 -0.062695
# deck_F      -0.138799 -0.171624 -0.117874 -0.115726  1.000000 -0.037864
# deck_G      -0.075194 -0.092977 -0.063858 -0.062695 -0.037864  1.000000
# alone_False  0.010971  0.103536  0.052246 -0.069470 -0.045787  0.130143
# alone_True  -0.010971 -0.103536 -0.052246  0.069470  0.045787 -0.130143
#
#              alone_False  alone_True
# survived        0.164475   -0.164475
# pclass         -0.055396    0.055396
# age            -0.191880    0.191880
# sibsp           0.651024   -0.651024
# parch           0.547771   -0.547771
# fare            0.384968   -0.384968
# sex_female      0.201423   -0.201423
# sex_male       -0.201423    0.201423
# who_child       0.240228   -0.240228
# who_man        -0.265228    0.265228
# who_woman       0.147245   -0.147245
# deck_A         -0.199484    0.199484
# deck_B          0.010971   -0.010971
# deck_C          0.103536   -0.103536
# deck_D          0.052246   -0.052246
# deck_E         -0.069470    0.069470
# deck_F         -0.045787    0.045787
# deck_G          0.130143   -0.130143
# alone_False     1.000000   -1.000000
# alone_True     -1.000000    1.000000

# %% [markdown]
# Remove deck from the model, it appears to have no correlation to 'survived', and also initially it had a lot of missing data.

# %%
df_1 = df_1.drop(columns = ['deck_A','deck_B','deck_C','deck_D','deck_E','deck_F','deck_G'])

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp     fare    who  alone  sex_female  \
# 1         1.0     1.0  female  38.0    1.0  71.2833  woman  False           1
# 3         1.0     1.0  female  35.0    1.0  53.1000  woman  False           1
# 6         0.0     1.0    male  54.0    0.0  51.8625    man   True           0
# 10        1.0     3.0  female   4.0    1.0  16.7000  child  False           1
# 11        1.0     1.0  female  58.0    0.0  26.5500  woman   True           1
# ..        ...     ...     ...   ...    ...      ...    ...    ...         ...
# 871       1.0     1.0  female  47.0    1.0  52.5542  woman  False           1
# 872       0.0     1.0    male  33.0    0.0   5.0000    man   True           0
# 879       1.0     1.0  female  56.0    0.0  83.1583  woman  False           1
# 887       1.0     1.0  female  19.0    0.0  30.0000  woman   True           1
# 889       1.0     1.0    male  26.0    0.0  30.0000    man   True           0
#
#      sex_male  who_child  who_man  who_woman  alone_False  alone_True
# 1           0          0        0          1            1           0
# 3           0          0        0          1            1           0
# 6           1          0        1          0            0           1
# 10          0          1        0          0            1           0
# 11          0          0        0          1            0           1
# ..        ...        ...      ...        ...          ...         ...
# 871         0          0        0          1            1           0
# 872         1          0        1          0            0           1
# 879         0          0        0          1            1           0
# 887         0          0        0          1            0           1
# 889         1          0        1          0            0           1
#
# [199 rows x 15 columns]

# %%
pearson_coef, p_value = stats.pearsonr(df_1['parch'], df_1['survived'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.038096545529770626  with a P-value of P = 0.5931849301181782

# %% [markdown]
# 'parch' has a P-value of 0.6, so it is insignificant and should be removed.

# %%
df_1
# Out:
#      survived  pclass     sex   age  sibsp     fare    who  alone  sex_female  \
# 1         1.0     1.0  female  38.0    1.0  71.2833  woman  False           1
# 3         1.0     1.0  female  35.0    1.0  53.1000  woman  False           1
# 6         0.0     1.0    male  54.0    0.0  51.8625    man   True           0
# 10        1.0     3.0  female   4.0    1.0  16.7000  child  False           1
# 11        1.0     1.0  female  58.0    0.0  26.5500  woman   True           1
# ..        ...     ...     ...   ...    ...      ...    ...    ...         ...
# 871       1.0     1.0  female  47.0    1.0  52.5542  woman  False           1
# 872       0.0     1.0    male  33.0    0.0   5.0000    man   True           0
# 879       1.0     1.0  female  56.0    0.0  83.1583  woman  False           1
# 887       1.0     1.0  female  19.0    0.0  30.0000  woman   True           1
# 889       1.0     1.0    male  26.0    0.0  30.0000    man   True           0
#
#      sex_male  who_child  who_man  who_woman  alone_False  alone_True
# 1           0          0        0          1            1           0
# 3           0          0        0          1            1           0
# 6           1          0        1          0            0           1
# 10          0          1        0          0            1           0
# 11          0          0        0          1            0           1
# ..        ...        ...      ...        ...          ...         ...
# 871         0          0        0          1            1           0
# 872         1          0        1          0            0           1
# 879         0          0        0          1            1           0
# 887         0          0        0          1            0           1
# 889         1          0        1          0            0           1
#
# [199 rows x 15 columns]

# %%
df_1 = df_1.drop(columns = ['sex','who','alone'])

# %%
df_1
# Out:
#      survived  pclass   age  sibsp     fare  sex_female  sex_male  who_child  \
# 1         1.0     1.0  38.0    1.0  71.2833           1         0          0
# 3         1.0     1.0  35.0    1.0  53.1000           1         0          0
# 6         0.0     1.0  54.0    0.0  51.8625           0         1          0
# 10        1.0     3.0   4.0    1.0  16.7000           1         0          1
# 11        1.0     1.0  58.0    0.0  26.5500           1         0          0
# ..        ...     ...   ...    ...      ...         ...       ...        ...
# 871       1.0     1.0  47.0    1.0  52.5542           1         0          0
# 872       0.0     1.0  33.0    0.0   5.0000           0         1          0
# 879       1.0     1.0  56.0    0.0  83.1583           1         0          0
# 887       1.0     1.0  19.0    0.0  30.0000           1         0          0
# 889       1.0     1.0  26.0    0.0  30.0000           0         1          0
#
#      who_man  who_woman  alone_False  alone_True
# 1          0          1            1           0
# 3          0          1            1           0
# 6          1          0            0           1
# 10         0          0            1           0
# 11         0          1            0           1
# ..       ...        ...          ...         ...
# 871        0          1            1           0
# 872        1          0            0           1
# 879        0          1            1           0
# 887        0          1            0           1
# 889        1          0            0           1
#
# [199 rows x 12 columns]

# %%
pclass_dummies = pd.get_dummies(df_1['pclass'], prefix = 'pclass')
pclass_dummies.sample(n=5)
# Out:
#      pclass_1.0  pclass_2.0  pclass_3.0
# 170           1           0           0
# 698           1           0           0
# 54            1           0           0
# 627           1           0           0
# 218           1           0           0

# %%
df_1 = pd.concat([df_1, pclass_dummies], axis =1)
df_1
# Out:
#      survived   age  sibsp     fare  sex_female  sex_male  who_child  who_man  \
# 1         1.0  38.0    1.0  71.2833           1         0          0        0
# 3         1.0  35.0    1.0  53.1000           1         0          0        0
# 6         0.0  54.0    0.0  51.8625           0         1          0        1
# 10        1.0   4.0    1.0  16.7000           1         0          1        0
# 11        1.0  58.0    0.0  26.5500           1         0          0        0
# ..        ...   ...    ...      ...         ...       ...        ...      ...
# 871       1.0  47.0    1.0  52.5542           1         0          0        0
# 872       0.0  33.0    0.0   5.0000           0         1          0        1
# 879       1.0  56.0    0.0  83.1583           1         0          0        0
# 887       1.0  19.0    0.0  30.0000           1         0          0        0
# 889       1.0  26.0    0.0  30.0000           0         1          0        1
#
#      who_woman  alone_False  alone_True  pclass_1.0  pclass_2.0  pclass_3.0
# 1            1            1           0           1           0           0
# 3            1            1           0           1           0           0
# 6            0            0           1           1           0           0
# 10           0            1           0           0           0           1
# 11           1            0           1           1           0           0
# ..         ...          ...         ...         ...         ...         ...
# 871          1            1           0           1           0           0
# 872          0            0           1           1           0           0
# 879          1            1           0           1           0           0
# 887          1            0           1           1           0           0
# 889          0            0           1           1           0           0
#
# [199 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import numpy as np

# %%
# Logistic Regression

# %%
feature_cols = ['age', 'sibsp','fare','sex_female', 'sex_male', 'who_child', 'who_man', 'who_woman', 'alone_False', 'alone_True','pclass_1.0','pclass_2.0','pclass_3.0']
Y = df_1['survived']

# %%
from sklearn.linear_model import LogisticRegression

# %%
df_1.iloc[:,0]
# Out:
# 1      1.0
# 3      1.0
# 6      0.0
# 10     1.0
# 11     1.0
#       ...
# 871    1.0
# 872    0.0
# 879    1.0
# 887    1.0
# 889    1.0
# Name: survived, Length: 199, dtype: float64

# %%
model_logistic = LogisticRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(df_1.iloc[:,1:], df_1.iloc[:,0], test_size = 0.2, random_state = 42)

# %%
df_1.shape, x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((199, 14), (159, 13), (159,), (40, 13), (40,))

# %%
model_logistic.fit(x_train, y_train)
# Out:
# /Users/salmanosman/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model_logistic.predict(x_test)

# %%
score = model_logistic.score(x_test, y_test)
print(score)
# Out:
# 0.775

# %%
# Calculating Confusion matrix for the model
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_test, predictions)
print(matrix)
# Out:
# [[ 4  1]
#  [ 8 27]]

# %%
# Decision Tree

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier(criterion='entropy')

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
prediction = model.predict(x_test)

# %%
score = model.score(x_test, y_test)
print(score)
# Out:
# 0.85

# %% [markdown]
# The Decision Tree model appears to be more accurate at predicting survival compared to the Logistic Regression model, with an accuracy of 85% compared to 77.5 for the Logistic model.

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model= RandomForestClassifier(n_estimators=1000)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
prediction = model.predict(x_test)

# %%
score = model.score(x_test, y_test)
print(score)
# Out:
# 0.75

# %%
# GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_clf = GradientBoostingClassifier(n_estimators=5, random_state=0)

# %%
gb_clf.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=5,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
prediction = gb_clf.predict(x_test)

# %%
score = gb_clf.score(x_test, y_test)
print(score)
# Out:
# 0.75

# %% [markdown]
# Gradient Boosting classifier and Random Forest yield an accuracy score of 75%
